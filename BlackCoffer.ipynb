# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_json("/content/jsondata.json")
df.shape
# Out:
# (1000, 17)

# %%
df=df.mask(df == '')      # Changed empty string to NaN value
df.head(5)
# Out:
#   end_year intensity       sector        topic  \
# 0      NaN         6       Energy          gas
# 1      NaN         6       Energy          oil
# 2      NaN         6       Energy  consumption
# 3      NaN         6  Environment          oil
# 4      NaN         6          NaN       market
#
#                                              insight  \
# 0                              Annual Energy Outlook
# 1                              Annual Energy Outlook
# 2                              Annual Energy Outlook
# 3  WRI Partnership Aims to Foster Supply Chain Tr...
# 4  N-Hexane Market Hit at a CAGR of 5% by 2024 - ...
#
#                                                  url            region  \
# 0  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 1  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# 2  http://www.eia.gov/outlooks/aeo/pdf/0383(2017)...  Northern America
# ...

# %% [markdown]
# ### **DATA ANALYSIS**

# %% [markdown]
# Pestle Analysis

# %%
sb.countplot(data=df, x="pestle")
plt.title("Pestle Analysis")
plt.xticks(fontsize=10, rotation = 75)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# Most recorded sector: which sector was observed more

# %%
#Most recorded sector

plt.figure(figsize=(16,4))
ax = sb.countplot(data = df, x = "sector")
for p in ax.patches:
   ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.title("Most recorded sector")
plt.xticks(fontsize=10, rotation = 75)
plt.yticks(fontsize=14)
# Out:
# (array([  0., 100., 200., 300., 400., 500., 600.]),
#  [Text(0, 0.0, '0'),
#   Text(0, 100.0, '100'),
#   Text(0, 200.0, '200'),
#   Text(0, 300.0, '300'),
#   Text(0, 400.0, '400'),
#   Text(0, 500.0, '500'),
#   Text(0, 600.0, '600')])

# %% [markdown]
# Sector vs Intensity: Determines the intensity of a sector at which they function

# %%
df['intensity'] = pd.to_numeric(df['intensity'])
plt.figure(figsize=(22,6))
sb.boxplot(x = "sector", y = "intensity", data =df)
plt.title("sector vs intensity: Determines the intensity of a sector at which they function")
plt.xticks(fontsize=10, rotation = 75)
plt.yticks(fontsize=14)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60'),
#   Text(0, 80.0, '80'),
#   Text(0, 100.0, '100'),
#   Text(0, 120.0, '120')])

# %% [markdown]
# region vs Intensity: Determines the intensity of a region at which they function

# %%
plt.figure(figsize=(22,6))
sb.boxplot(x = "region", y = "intensity", data =df)
plt.title("region vs intensity: Determines the intensity of a region at which they function")
plt.xticks(fontsize=10, rotation = 75)
plt.yticks(fontsize=14)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, -20.0, '−20'),
#   Text(0, 0.0, '0'),
#   Text(0, 20.0, '20'),
#   Text(0, 40.0, '40'),
#   Text(0, 60.0, '60'),
#   Text(0, 80.0, '80'),
#   Text(0, 100.0, '100'),
#   Text(0, 120.0, '120')])

# %% [markdown]
# country vs Intensity: Determines the intensity of a country at which they function

# %%
plt.figure(figsize=(22,6))
sb.boxplot(x = "country", y = "intensity", data =df)
plt.title("country vs intensity: Determines the intensity of a country at which they function")
plt.xticks(fontsize=10, rotation = 90)
plt.yticks(fontsize=14)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.,  70.,  80.]),
#  [Text(0, -10.0, '−10'),
#   Text(0, 0.0, '0'),
#   Text(0, 10.0, '10'),
#   Text(0, 20.0, '20'),
#   Text(0, 30.0, '30'),
#   Text(0, 40.0, '40'),
#   Text(0, 50.0, '50'),
#   Text(0, 60.0, '60'),
#   Text(0, 70.0, '70'),
#   Text(0, 80.0, '80')])

# %% [markdown]
# Sector based analysis

# %%
sb.set(style="ticks", color_codes=True)
g =sb.pairplot(df, hue ='sector')
g.fig.suptitle("sector analysis")
g.fig.set_size_inches(22,6)
plt.show()

# %% [markdown]
# Region based analysis

# %%
df['region'] = df['region'].str.replace('world','World') # world and World

sb.set(style="ticks", color_codes=True)
g =sb.pairplot(df, hue ='region')
g.fig.suptitle("  region analysis")
g.fig.set_size_inches(22,6)
plt.show()

# %% [markdown]
# Country based analysis

# %%
sb.set(style="ticks", color_codes=True)
g =sb.pairplot(df, hue ='country')
g.fig.suptitle("country analysis")
g.fig.set_size_inches(22,6)
plt.show()

# %%
df.isnull().sum()
# Out:
# end_year      742
# intensity      38
# sector        229
# topic          93
# insight         0
# url             0
# region        453
# start_year    690
# impact        966
# added           0
# published      74
# country       650
# relevance       1
# pestle         93
# source          1
# title           0
# likelihood     38
# dtype: int64

# %% [markdown]
# Visualizing availability of data in DataFrame (Dark means data's available)

# %%
sb.heatmap(df.isnull(), yticklabels=False)
plt.title("Checking availability of data in DataFrame (Dark means data's available)")
# Out:
# Text(0.5, 1.0, "Checking availability of data in DataFrame (Dark means data's available)")

# %% [markdown]
# Year can't be analyzed as it has a lot of NaN values which might provide wrong input(s) therefore, we'll skip that.

# %% [markdown]
# Instead we may plot relevance vs likelihood to establish an understanding what is more likely to happen considering its relevance.

# %%
df["likelihood"].value_counts()
# Out:
# 4    409
# 3    307
# 2    242
# 1      4
# Name: likelihood, dtype: int64

# %% [markdown]
# Relevance vs likelihood

# %%
sb.kdeplot(df["relevance"])
plt.title("Relevance vs likelihood")
plt.xlabel("relevance")
plt.ylabel("likelihood")
plt.show()

# %% [markdown]
# Topic published count: which topic was observed more

# %%
plt.figure(figsize=(32,6))
ax1 = sb.countplot(data= df, x = "topic")
for p in ax1.patches:
   ax1.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+0.2), color='black', size=9, ha="center")
plt.title("Topic published count")
plt.xticks(fontsize=10, rotation = 90)
plt.yticks(fontsize=14)

plt.show()
